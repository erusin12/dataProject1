# %%
# Dependencies and Setup
import numpy as np
import pandas as pd
import pytz

import os 
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import re
import hvplot
from scipy.stats import linregress
import folium
from folium.plugins import HeatMap


import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the CSV file located on BPD website into a DataFrame
arrest_data_df = pd.read_csv("Data/BPD_Arrests.csv")
# Display data
arrest_data_df.head()
# Out:
#               X              Y  arrestnumber   age gender race  \
# 0  1.401347e+06  608148.870493    23000037.0  39.0      M    B
# 1  1.401347e+06  608148.870493    23000039.0  50.0      M    B
# 2           NaN            NaN    23000010.0  27.0      M    B
# 3  1.417636e+06  595206.835862    23000050.0  42.0      M    B
# 4           NaN            NaN    22157188.0  31.0      M    B
#
#            arrestdatetime   arrestlocation  incidentoffence incidentlocation  \
# 0  2022/12/31 23:50:00+00  4000 OAKFORD ST  Unknown Offense  4000 OAKFORD ST
# 1  2022/12/31 23:50:00+00  4000 OAKFORD ST  Unknown Offense  4000 OAKFORD ST
# 2  2022/12/31 23:40:00+00              NaN  Unknown Offense              NaN
# 3  2022/12/31 23:15:00+00   500 DOLPHIN ST  Unknown Offense   500 DOLPHIN ST
# 4  2022/12/31 21:00:00+00              NaN  Unknown Offense              NaN
#
#    ...  chargedescription   district post    neighborhood latitude  longitude  \
# 0  ...                HGV  Northwest  621  West Arlington  39.3361   -76.6853
# 1  ...                HGV  Northwest  621  West Arlington  39.3361   -76.6853
# 2  ...  FAILURE TO APPEAR        NaN  NaN             NaN      NaN        NaN
# 3  ...                HGV    Central  123           Upton  39.3004   -76.6279
# 4  ...  FAILURE TO APPEAR        NaN  NaN             NaN      NaN        NaN
#
#           geolocation incidentnumber objectid  shape
# 0  (39.3361,-76.6853)       22L09338        1    NaN
# 1  (39.3361,-76.6853)       22L09338        2    NaN
# 2                 (,)            NaN        3    NaN
# 3  (39.3004,-76.6279)       22L09343        4    NaN
# 4                 (,)            NaN        5    NaN
#
# [5 rows x 21 columns]

# %%
# Define the desired time frame
start_date = pd.Timestamp("2018-01-01", tz="US/Eastern")
end_date = pd.Timestamp("2022-12-31", tz="US/Eastern")

# Convert date values to EST timezone
arrest_data_df["arrestdatetime"] = pd.to_datetime(arrest_data_df["arrestdatetime"], utc=False)

# Filter the data based on the time frame
sample_arrests = (arrest_data_df["arrestdatetime"] >= start_date) & (arrest_data_df["arrestdatetime"] <= end_date)

# Apply the filter to get the narrowed down data
narrowed_data = arrest_data_df[sample_arrests]
narrowed_data
# Out:
#                    X              Y  arrestnumber   age gender race  \
# 18               NaN            NaN    22157121.0  32.0      F    W
# 19      1.432299e+06  594505.863803    22157116.0  19.0      M    B
# 20      1.407598e+06  592946.031158    22000022.0  18.0      M    B
# 21      1.425747e+06  617095.607199    22000010.0  26.0      M    B
# 22               NaN            NaN    21168317.0  24.0      M    B
# ...              ...            ...           ...   ...    ...  ...
# 361706  1.427588e+06  603736.077990    18000078.0  23.0      F    B
# 361707           NaN            NaN    18000050.0  29.0      F    W
# 361708  1.432485e+06  603102.765099    18000045.0  46.0      M    B
# 361709  1.420414e+06  600936.840992    18000038.0  58.0      M    B
# 361710  1.438912e+06  590603.655722           NaN  30.0      M    U
#
#                   arrestdatetime      arrestlocation         incidentoffence  \
# 18     2022-12-31 03:53:00+00:00                 NaN         Unknown Offense
# 19     2022-12-31 00:09:00+00:00        600 CURLY ST         Unknown Offense
# 20     2021-12-31 23:14:00+00:00  2800 EDMONDSON AVE         Unknown Offense
# 21     2021-12-31 22:09:00+00:00   5700 NORTHWOOD DR         Unknown Offense
# 22     2021-12-31 21:00:00+00:00                 NaN         Unknown Offense
# ...                          ...                 ...                     ...
# 361706 2018-01-01 10:00:00+00:00     1600 E. 28TH ST  4ECOMMON ASSAULT
# 361707 2018-01-01 09:45:00+00:00                 NaN         Unknown Offense
# 361708 2018-01-01 08:00:00+00:00    3200 HARWELL AVE  79OTHER
# 361709 2018-01-01 05:30:00+00:00   2300 MARYLAND AVE  5DBURG. OTH. (FORCE)
# 361710 2018-01-01 05:00:00+00:00    5100 EASTERN AVE         Unknown Offense
#
#           incidentlocation  ...          chargedescription   district post  \
# 18                     NaN  ...          FAILURE TO APPEAR        NaN  NaN
# 19            600 CURLY ST  ...        MOTOR VEHICLE THEFT  Southeast  224
# 20      2800 EDMONDSON AVE  ...                        HGV    Western  721
# 21       5700 NORTHWOOD DR  ...                        HGV   Northern  523
# 22                     NaN  ...         RAPE SECOND DEGREE        NaN  NaN
# ...                    ...  ...                        ...        ...  ...
# 361706     1600 E. 28TH ST  ...                    ASSAULT  Northeast  411
# 361707                 NaN  ...  CDS:POSSESS-NOT MARIJUANA        NaN  NaN
# 361708    3200 HARWELL AVE  ...               AGG. ASSAULT  Northeast  432
# 361709   2300 MARYLAND AVE  ...             COMMON ASSAULT   Northern  514
# 361710    5100 EASTERN AVE  ...             Unknown Charge  Southeast  232
#
#                            neighborhood latitude  longitude  \
# 18                                  NaN      NaN        NaN
# 19                Ellwood Park/Monument  39.2983   -76.5761
# 20      Penrose/Fayette Street Outreach  39.2943   -76.6634
# 21                      Chinquapin Park  39.3604   -76.5989
# 22                                  NaN      NaN        NaN
# ...                                 ...      ...        ...
# 361706  Coldstream Homestead Montebello  39.3237   -76.5926
# 361707                              NaN      NaN        NaN
# 361708                    Belair-Edison  39.3219   -76.5753
# 361709                      Old Goucher  39.3161   -76.6180
# 361710                  Hopkins Bayview  39.2875   -76.5528
#
#                geolocation incidentnumber objectid  shape
# 18                     (,)            NaN       19    NaN
# 19      (39.2983,-76.5761)       22L07944       20    NaN
# 20      (39.2943,-76.6634)            NaN       21    NaN
# 21      (39.3604,-76.5989)            NaN       22    NaN
# 22                     (,)            NaN       23    NaN
# ...                    ...            ...      ...    ...
# 361706  (39.3237,-76.5926)       18A00107   361707    NaN
# 361707                 (,)            NaN   361708    NaN
# 361708  (39.3219,-76.5753)       18A00083   361709    NaN
# 361709   (39.3161,-76.618)       18E00079   361710    NaN
# 361710  (39.2875,-76.5528)            NaN   361711    NaN
#
# [78750 rows x 21 columns]

# %%
####Geographical Analysis

# %%
# Extract month and year from the arrestdatetime column
narrowed_data["arrest_month"] = narrowed_data["arrestdatetime"].dt.month
narrowed_data["arrest_year"] = narrowed_data["arrestdatetime"].dt.year
pd.set_option('display.precision', 0)
narrowed_data
# Out:
#             X       Y  arrestnumber  age gender race  \
# 18        NaN     NaN         2e+07   32      F    W
# 19      1e+06  594506         2e+07   19      M    B
# 20      1e+06  592946         2e+07   18      M    B
# 21      1e+06  617096         2e+07   26      M    B
# 22        NaN     NaN         2e+07   24      M    B
# ...       ...     ...           ...  ...    ...  ...
# 361706  1e+06  603736         2e+07   23      F    B
# 361707    NaN     NaN         2e+07   29      F    W
# 361708  1e+06  603103         2e+07   46      M    B
# 361709  1e+06  600937         2e+07   58      M    B
# 361710  1e+06  590604           NaN   30      M    U
#
#                   arrestdatetime      arrestlocation         incidentoffence  \
# 18     2022-12-31 03:53:00+00:00                 NaN         Unknown Offense
# 19     2022-12-31 00:09:00+00:00        600 CURLY ST         Unknown Offense
# 20     2021-12-31 23:14:00+00:00  2800 EDMONDSON AVE         Unknown Offense
# 21     2021-12-31 22:09:00+00:00   5700 NORTHWOOD DR         Unknown Offense
# 22     2021-12-31 21:00:00+00:00                 NaN         Unknown Offense
# ...                          ...                 ...                     ...
# 361706 2018-01-01 10:00:00+00:00     1600 E. 28TH ST  4ECOMMON ASSAULT
# 361707 2018-01-01 09:45:00+00:00                 NaN         Unknown Offense
# 361708 2018-01-01 08:00:00+00:00    3200 HARWELL AVE  79OTHER
# 361709 2018-01-01 05:30:00+00:00   2300 MARYLAND AVE  5DBURG. OTH. (FORCE)
# 361710 2018-01-01 05:00:00+00:00    5100 EASTERN AVE         Unknown Offense
#
#           incidentlocation  ... post                     neighborhood  \
# 18                     NaN  ...  NaN                              NaN
# 19            600 CURLY ST  ...  224            Ellwood Park/Monument
# 20      2800 EDMONDSON AVE  ...  721  Penrose/Fayette Street Outreach
# 21       5700 NORTHWOOD DR  ...  523                  Chinquapin Park
# 22                     NaN  ...  NaN                              NaN
# ...                    ...  ...  ...                              ...
# 361706     1600 E. 28TH ST  ...  411  Coldstream Homestead Montebello
# 361707                 NaN  ...  NaN                              NaN
# 361708    3200 HARWELL AVE  ...  432                    Belair-Edison
# 361709   2300 MARYLAND AVE  ...  514                      Old Goucher
# 361710    5100 EASTERN AVE  ...  232                  Hopkins Bayview
#
#        latitude longitude         geolocation  incidentnumber  objectid shape  \
# 18          NaN       NaN                 (,)             NaN        19   NaN
# 19           39       -77  (39.2983,-76.5761)        22L07944        20   NaN
# 20           39       -77  (39.2943,-76.6634)             NaN        21   NaN
# 21           39       -77  (39.3604,-76.5989)             NaN        22   NaN
# 22          NaN       NaN                 (,)             NaN        23   NaN
# ...         ...       ...                 ...             ...       ...   ...
# 361706       39       -77  (39.3237,-76.5926)        18A00107    361707   NaN
# 361707      NaN       NaN                 (,)             NaN    361708   NaN
# 361708       39       -77  (39.3219,-76.5753)        18A00083    361709   NaN
# 361709       39       -77   (39.3161,-76.618)        18E00079    361710   NaN
# 361710       39       -77  (39.2875,-76.5528)             NaN    361711   NaN
#
#        arrest_month  arrest_year
# 18               12         2022
# 19               12         2022
# 20               12         2021
# 21               12         2021
# 22               12         2021
# ...             ...          ...
# 361706            1         2018
# 361707            1         2018
# 361708            1         2018
# 361709            1         2018
# 361710            1         2018
#
# [78750 rows x 23 columns]

# %%
# Isolating the 2018 data for mapping
data_2018 = narrowed_data[narrowed_data['arrest_year'] == 2018]
# Out:
#             X       Y  arrestnumber  age gender race  \
# 102     1e+06  617759         2e+07   69      M    B
# 103     1e+06  594281         2e+07   17      M    B
# 104     1e+06  592802         2e+07   41      M    W
# 105     1e+06  612194         2e+07   42      M    B
# 106       NaN     NaN         2e+07   39      F    B
# ...       ...     ...           ...  ...    ...  ...
# 361706  1e+06  603736         2e+07   23      F    B
# 361707    NaN     NaN         2e+07   29      F    W
# 361708  1e+06  603103         2e+07   46      M    B
# 361709  1e+06  600937         2e+07   58      M    B
# 361710  1e+06  590604           NaN   30      M    U
#
#                   arrestdatetime      arrestlocation         incidentoffence  \
# 102    2018-12-31 23:30:00+00:00  6200 LAURELTON AVE         Unknown Offense
# 103    2018-12-31 23:30:00+00:00      500 LUZERNE ST     3AFROBB HWY-FIREARM
# 104    2018-12-31 22:00:00+00:00       200 SPRING CT         Unknown Offense
# 105    2018-12-31 21:30:00+00:00   5300 CORDELIA AVE  87NARCOTICS
# 106    2018-12-31 19:40:00+00:00                 NaN         Unknown Offense
# ...                          ...                 ...                     ...
# 361706 2018-01-01 10:00:00+00:00     1600 E. 28TH ST  4ECOMMON ASSAULT
# 361707 2018-01-01 09:45:00+00:00                 NaN         Unknown Offense
# 361708 2018-01-01 08:00:00+00:00    3200 HARWELL AVE  79OTHER
# 361709 2018-01-01 05:30:00+00:00   2300 MARYLAND AVE  5DBURG. OTH. (FORCE)
# 361710 2018-01-01 05:00:00+00:00    5100 EASTERN AVE         Unknown Offense
#
#           incidentlocation  ... post                     neighborhood  \
# 102     6200 LAURELTON AVE  ...  423                   Hamilton Hills
# 103         500 LUZERNE ST  ...  221                   Mcelderry Park
# 104          200 SPRING CT  ...  212                  Dunbar-Broadway
# 105      5300 CORDELIA AVE  ...  633                        Arlington
# 106                    NaN  ...  NaN                              NaN
# ...                    ...  ...  ...                              ...
# 361706     1600 E. 28TH ST  ...  411  Coldstream Homestead Montebello
# 361707                 NaN  ...  NaN                              NaN
# 361708    3200 HARWELL AVE  ...  432                    Belair-Edison
# 361709   2300 MARYLAND AVE  ...  514                      Old Goucher
# 361710    5100 EASTERN AVE  ...  232                  Hopkins Bayview
#
#        latitude longitude         geolocation  incidentnumber  objectid shape  \
# 102          39       -77  (39.3621,-76.5651)             NaN       103   NaN
# 103          39       -77   (39.2977,-76.581)        18L11147       104   NaN
# 104          39       -77  (39.2937,-76.5979)             NaN       105   NaN
# 105          39       -77  (39.3472,-76.6832)        18L11226       106   NaN
# 106         NaN       NaN                 (,)             NaN       107   NaN
# ...         ...       ...                 ...             ...       ...   ...
# 361706       39       -77  (39.3237,-76.5926)        18A00107    361707   NaN
# 361707      NaN       NaN                 (,)             NaN    361708   NaN
# 361708       39       -77  (39.3219,-76.5753)        18A00083    361709   NaN
# 361709       39       -77   (39.3161,-76.618)        18E00079    361710   NaN
# 361710       39       -77  (39.2875,-76.5528)             NaN    361711   NaN
#
#        arrest_month  arrest_year
# 102              12         2018
# 103              12         2018
# 104              12         2018
# 105              12         2018
# 106              12         2018
# ...             ...          ...
# 361706            1         2018
# 361707            1         2018
# 361708            1         2018
# 361709            1         2018
# 361710            1         2018
#
# [20909 rows x 23 columns]

# %%
# Define latitutde and longitude and remove the nulls
latitudes = data_2018['latitude'].dropna()  
longitudes = data_2018['longitude'].dropna()  

# Create a map
map_obj = folium.Map(location=[latitudes.mean(), longitudes.mean()], zoom_start=5)

# Combine latitudes and longitudes into list
points = list(zip(latitudes, longitudes))

# Display the map
HeatMap(points, radius=6, blur=4).add_to(map_obj)
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_55d73d3eaaf2a84ae56e2800fe867ad3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_55d73d3eaaf2a84ae56e2800fe867ad3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_55d73d3eaaf2a84ae56e2800fe867ad3 = L.map(
#                 &quot;map_55d73d3eaaf2a84ae56e2800fe867ad3&quot;,
#                 {
#                     center: [37.760972747252744, -73.61035876123876],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_586b25ad0df46e974e921d0b9143607d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_55d73d3eaaf2a84ae56e2800fe867ad3);
#
#
#             var heat_map_6c5bdcd3204b298cd324ce60fc4277ea = L.heatLayer(
#                 [[39.3621, -76.5651], [39.2977, -76.581], [39.2937, -76.5979], [39.3472, -76.6832], [39.3053, -76.6695], [39.2881, -76.6442], [39.237, -76.6036], [39.2368, -76.603], [39.2826, -76.6485], [0.0, 0.0], [39.308, -76.6542], [39.3088, -76.5917], [39.3127, -76.5859], [39.3025, -76.666], [39.2746, -76.6216], [39.2738, -76.6278], [39.2962, -76.57], [39.3092, -76.6695], [39.3423, -76.6735], [39.2916, -76.5647], [39.3288, -76.5642], [39.2824, -76.5366], [39.3599, -76.7057], [39.3186, -76.5991], [39.2879, -76.6514], [39.2857, -76.6554], [39.3219, -76.5737], [39.2799, -76.6671], [39.3385, -76.6803], [39.3043, -76.6398], [39.336, -76.6058], [39.2543, -76.6486], [39.282, -76.6814], [39.2905, -76.5925], [39.294, -76.5882], [39.3014, -76.6281], [39.2953, -76.57], [39.3455, -76.6095], [39.283, -76.6528], [39.3219, -76.5729], [39.2853, -76.6424], [39.2915, -76.5964], [39.3482, -76.6707], [39.2939, -76.6959], [39.3101, -76.6361], [39.2876, -76.6209], [39.285, -76.6466], [39.3102, -76.6753], [39.2738, -76.6278], [39.291, -76.6208], [39.2954, -76.5939], [39.2915, -76.5964], [39.2923, -76.5972], [39.3137, -76.6606], [39.2978, -76.5835], [39.2806, -76.6957], [39.3038, -76.6014], [39.2739, -76.614], [39.2872, -76.5982], [39.2899, -76.61], [39.3031, -76.6342], [39.2935, -76.5677], [39.2989, -76.5822], [39.342, -76.6825], [39.3081, -76.6695], [39.2899, -76.61], [39.2986, -76.582], [39.3164, -76.646], [39.3097, -76.6462], [39.2848, -76.
# 77      1e+06  593194         2e+07   17      M    B
# 78      1e+06  593194         2e+07   16      M    B
# ...       ...     ...           ...  ...    ...  ...
# 361677  1e+06  593520         2e+07   42      M    U
# 361678  1e+06  596939         2e+07   44      M    B
# 361679  3e+07 -948896         2e+07   31      F    B
# 361680    NaN     NaN         2e+07   49      M    B
# 361681  1e+06  612418         2e+07   31      M    B
#
#                   arrestdatetime    arrestlocation         incidentoffence  \
# 74     2019-12-31 23:56:00+00:00  3300 BRIGHTON ST  4ECOMMON ASSAULT
# 75     2019-12-31 23:27:00+00:00               NaN         Unknown Offense
# 76     2019-12-31 22:21:00+00:00       0 HOWARD ST  81RECOVERED PROPERTY
# 77     2019-12-31 21:30:00+00:00   2900 FAYETTE ST  54ARMED PERSON
# 78     2019-12-31 21:30:00+00:00   2900 FAYETTE ST  54ARMED PERSON
# ...                          ...               ...                     ...
# 361677 2019-01-01 00:20:00+00:00    200 KENWOOD ST  4ECOMMON ASSAULT
# 361678 2019-01-01 00:11:00+00:00   1200 LUZERNE ST  54ARMED PERSON
# 361679 2019-01-01 00:10:00+00:00    400 KENWOOD ST         Unknown Offense
# 361680 2019-01-01 00:08:00+00:00               NaN  54ARMED PERSON
# 361681 2019-01-01 00:04:00+00:00  4800 CROWSON AVE  54ARMED PERSON
#
#         incidentlocation  ... post           neighborhood latitude longitude  \
# 74      3300 BRIGHTON ST  ...  813               Rosemont       39       -77
# 75                   NaN  ...  NaN                    NaN      NaN       NaN
# 76           0 HOWARD ST  ...  NaN                    NaN        0         0
# 77       2900 FAYETTE ST  ...  224  Ellwood Park/Monument       39       -77
# 78       2900 FAYETTE ST  ...  224  Ellwood Park/Monument       39       -77
# ...                  ...  ...  ...                    ...      ...       ...
# 361677    200 KENWOOD ST  ...  221         Mcelderry Park       39       -77
# 361678   1200 LUZERNE ST  ...  332                  Berea       39       -77
# 361679    400 KENWOOD ST  ...  NaN                    NaN        0         0
# 361680               NaN  ...  NaN                    NaN      NaN       NaN
# 361681  4800 CROWSON AVE  ...  521         Radnor-Winston       39       -77
#
#                geolocation  incidentnumber  objectid shape arrest_month  \
# 74       (39.305,-76.6731)        20A00003        75   NaN           12
# 75                     (,)             NaN        76   NaN           12
# 76                   (0,0)        19L09538        77   NaN           12
# 77      (39.2947,-76.5763)        19L09488        78   NaN           12
# 78      (39.2947,-76.5763)        19L09488        79   NaN           12
# ...                    ...             ...       ...   ...          ...
# 361677   (39.2956,-76.578)        19A00022    361678   NaN            1
# 361678   (39.305,-76.5815)        19A00005    361679   NaN            1
# 361679               (0,0)        19A00011    361680   NaN            1
# 361680                 (,)        19A00012    361681   NaN            1
# 361681  (39.3476,-76.6112)        19A00012    361682   NaN            1
#
#         arrest_year
# 74             2019
# 75             2019
# 76             2019
# 77             2019
# 78             2019
# ...             ...
# 361677         2019
# 361678         2019
# 361679         2019
# 361680         2019
# 361681         2019
#
# [19601 rows x 23 columns]

# %%
# Define latitutde and longitude and remove the nulls
latitudes = data_2019['latitude'].dropna()  
longitudes = data_2019['longitude'].dropna()  

# Create a map
map_obj = folium.Map(location=[latitudes.mean(), longitudes.mean()], zoom_start=5)

# Combine latitudes and longitudes ito list
points = list(zip(latitudes, longitudes))

# Display the map
HeatMap(points, radius=6, blur=4).add_to(map_obj)
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map
# ...                          ...                    ...
# 361622 2020-01-01 02:15:00+00:00            300 33RD ST
# 361623 2020-01-01 01:00:00+00:00                    NaN
# 361624 2020-01-01 00:43:00+00:00                    NaN
# 361625 2020-01-01 00:30:00+00:00      2400 CHRISTIAN ST
# 361626 2020-01-01 00:10:00+00:00      2500 BALTIMORE ST
#
#                incidentoffence       incidentlocation  ... post  \
# 42       96BINVESTIGATIVE STOP       2900 PRESBURY ST  ...  813
# 43      5FBURG. OTH. (NOFORCE)          900 MONROE ST  ...  722
# 44             Unknown Offense  1000 PINE HEIGHTS AVE  ...  832
# 45             Unknown Offense     700 CHERRY HILL RD  ...  922
# 46             Unknown Offense     700 CHERRY HILL RD  ...  922
# ...                        ...                    ...  ...  ...
# 361622         Unknown Offense            300 33RD ST  ...  512
# 361623         Unknown Offense                    NaN  ...  NaN
# 361624         Unknown Offense                    NaN  ...  NaN
# 361625  4CAGG. ASSLT.- OTH.         2400 CHRISTIAN ST  ...  834
# 361626  54ARMED PERSON              2500 BALTIMORE ST  ...  835
#
#                       neighborhood latitude longitude         geolocation  \
# 42      Northwest Community Action       39       -77  (39.3074,-76.6661)
# 43               Midtown-Edmondson       39       -77  (39.2991,-76.6477)
# 44                     Violetville       39       -77  (39.2696,-76.6755)
# 45                     Cherry Hill       39       -77  (39.2499,-76.6241)
# 46                     Cherry Hill       39       -77  (39.2499,-76.6241)
# ...                            ...      ...       ...                 ...
# 361622                  Oakenshawe       39       -77  (39.3285,-76.6134)
# 361623                         NaN      NaN       NaN                 (,)
# 361624                         NaN      NaN       NaN                 (,)
# 361625                    Millhill       39       -77  (39.2804,-76.6539)
# 361626                Shipley Hill       39       -77  (39.2879,-76.6566)
#
#         incidentnumber  objectid shape arrest_month  arrest_year
# 42            20A08559        43   NaN           12         2020
# 43            21L07949        44   NaN           12         2020
# 44                 NaN        45   NaN           12         2020
# 45            20L08536        46   NaN           12         2020
# 46            20L08536        47   NaN           12         2020
# ...                ...       ...   ...          ...          ...
# 361622             NaN    361623   NaN            1         2020
# 361623             NaN    361624   NaN            1         2020
# 361624             NaN    361625   NaN            1         2020
# 361625        20A00013    361626   NaN            1         2020
# 361626        20A00009    361627   NaN            1         2020
#
# [13935 rows x 23 columns]

# %%
# Define latitutde and longitude and remove the nulls
latitudes = data_2020['latitude'].dropna()  
longitudes = data_2020['longitude'].dropna()  

# Create a map
map_obj = folium.Map(location=[latitudes.mean(), longitudes.mean()], zoom_start=5)

# Combine latitudes and longitudes ito list
points = list(zip(latitudes, longitudes))

# Display the map
HeatMap(points, radius=6, blur=4).add_to(map_obj)
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2648cb3e36c20b270a4b355d8f8f37f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2648cb3e36c20b270a4b355d8f8f37f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2648cb3e36c20b270a4b355d8f8f37f1 = L.map(
#                 &quot;map_2648cb3e36c20b270a4b355d8f8f37f1&quot;,
#                 {
#                     center: [37.30088721780088, -72.71213815169726],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e25a502ec2411b68a53c83c071580e2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_
76.5501], [39.3389, -76.679], [39.2847, -76.5692], [39.3471, -76.607], [0.0, 0.0], [39.3031, -76.6344], [39.2937, -76.6222], [39.3132, -76.6036], [39.3211, -76.5653], [39.3211, -76.5653], [39.3344, -76.6057], [39.3313, -76.6584], [39.2511, -76.6466], [39.299, -76.5749], [39.2797, -76.616], [0.0, 0.0], [0.0, 0.0], [39.2841, -76.6469], [39.3043, -76.6359], [39.2979, -76.6473], [39.2979, -76.643], [39.2803, -76.6335], [39.325, -76.5404], [39.3361, -76.6661], [39.3046, -76.6674], [39.2866, -76.6314], [39.2957, -76.5823], [39.2785, -76.6124], [39.2977, -76.5742], [39.321, -76.565], [39.3379, -76.6025], [39.3696, -76.6816], [39.2803, -76.5352], [39.3102, -76.6754], [39.3012, -76.6403], [39.3304, -76.6363], [39.31, -76.6407], [39.3426, -76.6766], [39.2888, -76.6359], [39.2928, -76.6226], [39.3626, -76.5534], [39.3518, -76.5622], [39.2828, -76.5729], [39.2929, -76.6215], [39.2775, -76.6161], [39.3294, -76.5414], [39.3528, -76.681], [39.2942, -76.6785], [39.3222, -76.5399], [39.3003, -76.6389], [39.3412, -76.6655], [39.3059, -76.6378], [39.3315, -76.6952], [39.3412, -76.6655], [39.3226, -76.5899], [39.3319, -76.5976], [39.341, -76.6659], [39.3485, -76.565], [39.2715, -76.537],

# %%
# Isolating the 2021 data for mapping
data_2021 = narrowed_data[narrowed_data['arrest_year'] == 2021]
# Out:
#             X       Y  arrestnumber  age gender race  \
# 20      1e+06  592946         2e+07   18      M    B
# 21      1e+06  617096         2e+07   26      M    B
# 22        NaN     NaN         2e+07   24      M    B
# 23        NaN     NaN         2e+07   28      M    B
# 24        NaN     NaN         2e+07   28      M    B
# ...       ...     ...           ...  ...    ...  ...
# 361590  1e+06  597715         2e+07   22      F    B
# 361591  1e+06  589289         2e+07   31      M    W
# 361592    NaN     NaN         2e+07   27      M    B
# 361593  1e+06  600082         2e+07   51      M    B
# 361594  1e+06  596183         2e+07   23      M    B
#
#                   arrestdatetime         arrestlocation  \
# 20     2021-12-31 23:14:00+00:00     2800 EDMONDSON AVE
# 21     2021-12-31 22:09:00+00:00      5700 NORTHWOOD DR
# 22     2021-12-31 21:00:00+00:00                    NaN
# 23     2021-12-31 18:21:00+00:00                    NaN
# 24     2021-12-31 18:21:00+00:00                    NaN
# ...                          ...                    ...
# 361590 2021-01-01 02:13:00+00:00       2900 PRESBURY ST
# 361591 2021-01-01 02:12:00+00:00        2400 FOSTER AVE
# 361592 2021-01-01 01:31:00+00:00                    NaN
# 361593 2021-01-01 00:50:00+00:00      800 NEWINGTON AVE
# 361594 2021-01-01 00:40:00+00:00  1600 PENNSYLVANIA AVE
#
#                incidentoffence       incidentlocation  ... post  \
# 20             Unknown Offense     2800 EDMONDSON AVE  ...  721
# 21             Unknown Offense      5700 NORTHWOOD DR  ...  523
# 22             Unknown Offense                    NaN  ...  NaN
# 23             Unknown Offense                    NaN  ...  NaN
# 24             Unknown Offense                    NaN  ...  NaN
# ...                        ...                    ...  ...  ...
# 361590         Unknown Offense       2900 PRESBURY ST  ...  813
# 361591  4ECOMMON ASSAULT              2400 FOSTER AVE  ...  214
# 361592         Unknown Offense                    NaN  ...  NaN
# 361593  49FAMILY DISTURBANCE        800 NEWINGTON AVE  ...  133
# 361594  54ARMED PERSON          1600 PENNSYLVANIA AVE  ...  123
#
#                            neighborhood latitude longitude  \
# 20      Penrose/Fayette Street Outreach       39       -77
# 21                      Chinquapin Park       39       -77
# 22                                  NaN      NaN       NaN
# 23                                  NaN      NaN       NaN
# 24                                  NaN      NaN       NaN
# ...                                 ...      ...       ...
# 361590       Northwest Community Action       39       -77
# 361591                           Canton       39       -77
# 361592                              NaN      NaN       NaN
# 361593                   Reservoir Hill       39       -77
# 361594                            Upton       39       -77
#
#                geolocation  incidentnumber  objectid shape arrest_month  \
# 20      (39.2943,-76.6634)             NaN        21   NaN           12
# 21      (39.3604,-76.5989)             NaN        22   NaN           12
# 22                     (,)             NaN        23   NaN           12
# 23                     (,)             NaN        24   NaN           12
# 24                     (,)             NaN        25   NaN           12
# ...                    ...             ...       ...   ...          ...
# 361590  (39.3074,-76.6661)             NaN    361591   NaN            1
# 361591   (39.284,-76.5827)        21A00040    361592   NaN            1
# 361592                 (,)             NaN    361593   NaN            1
# 361593  (39.3138,-76.6325)        21A00015    361594   NaN            1
# 361594  (39.3031,-76.6344)        21A00013    361595   NaN            1
#
#         arrest_year
# 20             2021
# 21             2021
# 22             2021
# 23             2021
# 24             2021
# ...             ...
# 361590         2021
# 361591         2021
# 361592         2021
# 361593         2021
# 361594         2021
#
# [11797 rows x 23 columns]

# %%
# Define latitutde and longitude and remove the nulls
latitudes = data_2021['latitude'].dropna()  
longitudes = data_2021['longitude'].dropna()  

# Create a map
map_obj = folium.Map(location=[latitudes.mean(), longitudes.mean()], zoom_start=5)

# Combine latitudes and longitudes ito list
points = list(zip(latitudes, longitudes))

# Display the map
HeatMap(points, radius=6, blur=4).add_to(map_obj)
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_888229cf69da44cffbea83d9956d2205 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_888229cf69da44cffbea83d9956d2205&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_888229cf69da44cffbea83d9956d2205 = L.map(
#                 &quot;map_888229cf69da44cffbea83d9956d2205&quot;,
#                 {
#                     center: [37.09101786496714, -72.30303634734116],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c647e7f90abfa55c47a61cc51a363e4b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_888229cf69da44cffbea83d9956d2205);
#
#
#             var heat_map_53ca0cf82493e8388c61886ec542d6ba = L.heatLayer(
#                 [[39.2943, -76.6634], [39.3604, -76.5989], [39.3124, -76.6345], [39.2946, -76.561], [39.3181, -76.5879], [39.3643, -76.6715], [39.293, -76.662], [39.3019, -76.6331], [39.2947, -76.5878], [39.2835, -76.5821], [39.3024, -76.5967], [39.2917, -76.6181], [39.2959, -76.6185], [39.3305, -76.6917], [39.3252, -76.5612], [39.2866, -76.656], [39.3465, -76.5442], [39.2779, -76.6587], [39.3422, -76.567], [39.2738, -76.6278], [39.3103, -76.6467], [39.3151, -76.595], [39.295, -76.6534], [39.2801, -76.6506], [39.2801, -76.6506], [39.3044, -76.
.6368], [39.2822, -76.6435], [39.3182, -76.6066], [39.342, -76.6781], [39.3036, -76.5409], [39.3223, -76.6801], [39.2974, -76.6629], [39.243, -76.6275], [39.2896, -76.6096], [39.2904, -76.6077], [39.226, -76.5886], [39.2904, -76.6077], [39.2904, -76.6077], [39.2984, -76.6322], [39.2429, -76.6252], [39.3234, -76.5716], [39.2876, -76.5568], [39.3141, -76.6158], [39.2803, -76.6512], [39.3146, -76.6084], [0.0, 0.0], [39.2907, -76.6561], [39.3152, -76.5778], [39.2992, -76.6536], [39.2992, -76.6536], [39.3006, -76.6245], [39.2959, -76.7088], [39.2984, -76.5739], [39.3007, -76.6397], [39.2963, -76.6863], [39.3003, -76.5804], [39.2989, -76.5822], [39.3623, -76.6128], [39.3133, -

# %%
# Isolating the 2022 data for mapping
data_2022 = narrowed_data[narrowed_data['arrest_year'] == 2022]
data_2022
# Out:
#             X       Y  arrestnumber  age gender race  \
# 18        NaN     NaN         2e+07   32      F    W
# 19      1e+06  594506         2e+07   19      M    B
# 682     1e+06  595270         2e+07   24      F    B
# 683       NaN     NaN         2e+07   70      M    B
# 684       NaN     NaN         2e+07   18      M    B
# ...       ...     ...           ...  ...    ...  ...
# 361561  1e+06  602440         2e+07   41      M    A
# 361562    NaN     NaN         2e+07   53      F    B
# 361563  1e+06  612483         2e+07   39      M    B
# 361564  1e+06  595461         2e+07   21      M    B
# 361565  1e+06  595027         2e+07   35      M    B
#
#                   arrestdatetime    arrestlocation         incidentoffence  \
# 18     2022-12-31 03:53:00+00:00               NaN         Unknown Offense
# 19     2022-12-31 00:09:00+00:00      600 CURLY ST         Unknown Offense
# 682    2022-12-30 23:25:00+00:00    800 ASHLAND CT         Unknown Offense
# 683    2022-12-30 23:09:00+00:00               NaN         Unknown Offense
# 684    2022-12-30 23:00:00+00:00               NaN         Unknown Offense
# ...                          ...               ...                     ...
# 361561 2022-01-01 06:15:00+00:00   400 LORRAINE ST  4ECOMMON ASSAULT
# 361562 2022-01-01 05:25:00+00:00               NaN         Unknown Offense
# 361563 2022-01-01 04:36:00+00:00   5300 NELSON AVE  4BAGG. ASSLT.- CUT
# 361564 2022-01-01 01:18:00+00:00    1200 ETTING ST         Unknown Offense
# 361565 2022-01-01 00:03:00+00:00  1000 STODDARD CT         Unknown Offense
#
#         incidentlocation  ... post           neighborhood latitude longitude  \
# 18                   NaN  ...  NaN                    NaN      NaN       NaN
# 19          600 CURLY ST  ...  224  Ellwood Park/Monument       39       -77
# 682       800 ASHLAND CT  ...  324                Oldtown       39       -77
# 683                  NaN  ...  NaN                    NaN      NaN       NaN
# 684                  NaN  ...  NaN                    NaN      NaN       NaN
# ...                  ...  ...  ...                    ...      ...       ...
# 361561   400 LORRAINE ST  ...  513                Harwood       39       -77
# 361562               NaN  ...  NaN                    NaN      NaN       NaN
# 361563   5300 NELSON AVE  ...  633              Arlington       39       -77
# 361564    1200 ETTING ST  ...  123                  Upton       39       -77
# 361565  1000 STODDARD CT  ...  123                  Upton       39       -77
#
#                geolocation  incidentnumber  objectid shape arrest_month  \
# 18                     (,)             NaN        19   NaN           12
# 19      (39.2983,-76.5761)        22L07944        20   NaN           12
# 682     (39.3005,-76.6053)        22L09103       683   NaN           12
# 683                    (,)             NaN       684   NaN           12
# 684                    (,)             NaN       685   NaN           12
# ...                    ...             ...       ...   ...          ...
# 361561  (39.3202,-76.6097)        22A00098    361562   NaN            1
# 361562                 (,)             NaN    361563   NaN            1
# 361563   (39.348,-76.6855)        22A00045    361564   NaN            1
# 361564  (39.3011,-76.6287)        22A00025    361565   NaN            1
# 361565  (39.2999,-76.6257)        22A00005    361566   NaN            1
#
#         arrest_year
# 18             2022
# 19             2022
# 682            2022
# 683            2022
# 684            2022
# ...             ...
# 361561         2022
# 361562         2022
# 361563         2022
# 361564         2022
# 361565         2022
#
# [12508 rows x 23 columns]

# %%
# Define latitutde and longitude and remove the nulls
latitudes = data_2022['latitude'].dropna()  
longitudes = data_2022['longitude'].dropna()  

# Create a map
map_obj = folium.Map(location=[latitudes.mean(), longitudes.mean()], zoom_start=5)

# Combine latitudes and longitudes ito list
points = list(zip(latitudes, longitudes))

# Display the map
HeatMap(points, radius=6, blur=4).add_to(map_obj)
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69ebc5d7fd1cbbd821c1431d221961ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69ebc5d7fd1cbbd821c1431d221961ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69ebc5d7fd1cbbd821c1431d221961ee = L.map(
#                 &quot;map_69ebc5d7fd1cbbd821c1431d221961ee&quot;,
#                 {
#                     center: [37.01936792137181, -72.16687047260561],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b60b18717111d178463d622f31cbf3cb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_69ebc5d7fd1cbbd821c1431d221961ee);
#
#
#             var heat_map_0ac28a0657d02987ff9a23e9fd07ff86 = L.heatLayer(
#                 [[39.2983, -76.5761], [39.3005, -76.6053], [39.3522, -76.56], [39.3084, -76.5991], [39.2667, -76.6149], [39.3101, -76.6371], [39.2891, -76.5847], [39.3085, -76.6259], [39.2868, -76.6523], [39.288, -76.5394], [39.3399, -76.5494], [39.2829, -76.6423], [39.2861, -76.6546], [39.3571, -76.7057], [39.2316, -76.6027], [39.2835, -76.6561], [0.0, 0.0], [39.3091, -76.6271], [39.2992, -76.5765], [39.3216, -76.5934], [0.0, 0.0], [39.2302, -76.6028], [39.3152, -76.5447], [39.2964, -76.5816], [39.3559, -76.7043], [39.3411, -76.6713], [39.2887, -76.6585], [39.2972, -76.5712], [39.3456, -76.6832], [39.3423, -76.669], [0.0, 0.0], [39.325, -76.5404], [39.3314, -76.6958], [39.3314, -76.6958], [39.3314, -76.6958], [39.3111, -76.6194], [39.288, -76.5394], [39.3081, -76.6437], [39.3111, -76.6194], [0.0, 0.0], [0.0, 0.0], [39.3716, -76.5599], [39.3068, -76.6369], [39.2925, -76.6134], [39.2883, -76.5655], [39.304, -76.6354], [39.3717, -76.5383], [39.335, -76.5409], [39.3053, -76.6471], [39.299, -76.624], [39.2977, -76.585], [39.2944, -76.6688], [39.3102, -76.6412], [39.3416, -76.6851], [39.3102, -76.6412], [39.3492, -76.5959], [39.3482, -76.5985], [39.2897, -76.6454], [39.3055, -